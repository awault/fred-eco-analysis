# %%
from dotenv import load_dotenv
from fredapi import Fred
import os

# Load environment variables
load_dotenv(dotenv_path='../.env')
# Out:
# True

# %%
fred_api_key = os.getenv('FRED_API_KEY')
fred = Fred(api_key=str(fred_api_key))
data = fred.get_series('PERMIT')
print(data.tail())
# Out:
# 2024-09-01    1425.0
# 2024-10-01    1419.0
# 2024-11-01    1493.0
# 2024-12-01    1482.0
# 2025-01-01    1473.0
# dtype: float64

# %%
# Search for Data Series 
fred.search('permit')
# Out:
#                         id  ...                                              notes
# series id                   ...
# PERMIT              PERMIT  ...  Starting with the 2005-02-16 release, the seri...
# PERMITNSA        PERMITNSA  ...                                               None
# PERMIT1            PERMIT1  ...  Starting with the 2005-02-16 release, the seri...
# PERMIT1NSA      PERMIT1NSA  ...                                               None
# CABPPRIVSA      CABPPRIVSA  ...  This series represents the total number of bui...
# ...                    ...  ...                                                ...
# BPPRIV048163  BPPRIV048163  ...  This series represents the total number of bui...
# BPPRIV021121  BPPRIV021121  ...  This series represents the total number of bui...
# BPPRIV036003  BPPRIV036003  ...  This series represents the total number of bui...
# BPPRIV048217  BPPRIV048217  ...  This series represents the total number of bui...
# BPPRIV028063  BPPRIV028063  ...  This series represents the total number of bui...
#
# [1000 rows x 15 columns]
